# %%
import numpy as np

# %%
c_80 = np.load('c_80.npy')
c_20 = np.load('c_20.npy')

# %%
loss = np.load('acc.npy')

# %%
loss
# Out:
# array([[0.88929999, 0.91850001, 0.94069999, 0.94520003, 0.        ],
#        [0.88690001, 0.91839999, 0.93870002, 0.95060003, 0.        ],
#        [0.8527    , 0.92680001, 0.92790002, 0.94230002, 0.        ],
#        [0.86870003, 0.92790002, 0.9375    , 0.9443    , 0.        ],
#        [0.88139999, 0.92009997, 0.93540001, 0.        , 0.        ]])

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(10,2, figsize=(10,8))
display_a = c_20.reshape((20,28,28,1))
for i,ax in enumerate(axes.flat):
    ax.imshow(display_a[i])

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(10,8, figsize=(10,8))
display_a = c_80.reshape((80,28,28,1))
for i,ax in enumerate(axes.flat):
    ax.imshow(display_a[i])

# %%
import numpy as np

# %%
c_40 = np.load('/home/dm1/shikhar_backup/shikhar/CCMCL/logs/CompositionalBuffer/FashionMNIST/c_40.npy')

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(10,4, figsize=(10,8))
display_a = c_40.reshape((40,28,28,1))
for i,ax in enumerate(axes.flat):
    ax.imshow(display_a[i])
